# %% [markdown]
# # Wine Quality ML Proof Notebook\n\nThis local placeholder notebook points to the full project notebook used as ML proof.\n\n- Source: https://github.com/Pratham-Arun/Wine-Quality-Prediction-System/blob/main/Wine_Quality_Prediction_Machine_Learning.ipynb
